# %%
import requests
import pandas as pd

# %%
requests.get('https://api.themoviedb.org/3/movie/popular?api_key=c5020a2401b402b3e7ca03a9269573c6&language=en-US&page=10')
# Out:
# <Response [200]>

# %%
df = pd.DataFrame()

# %%
# d={'name':['Rahul','Rohit'],'Age':[34,56]}
# df=pd.DataFrame(d)
# df

# %%
#.json()
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=c5020a2401b402b3e7ca03a9269573c6&language=en-US&page=10').json()

# %%
response
# Out:
# {'page': 10,
#  'results': [{'adult': False,
#    'backdrop_path': '/10c3Hrn1clcSg9PJVl16TARq8Oe.jpg',
#    'genre_ids': [10749, 35],
#    'id': 648743,
#    'original_language': 'es',
#    'original_title': '¿Qué culpa tiene el karma?',
#    'overview': 'The travails of Sara, a frustrated fashion designer who blames karma for her bad luck. Fate will put her face to face with her sister, Lucy, who enjoys very different luck, and in a series of events and reunions that will lead her to make a radical decision.',
#    'popularity': 133.503,
#    'poster_path': '/7BtnZMhU4V8Mq33609UpWvLSHE3.jpg',
#    'release_date': '2022-08-03',
#    'title': "Don't Blame Karma!",
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 168},
#   {'adult': False,
#    'backdrop_path': '/kdbLf3aTQsEXqYlH9vA4fzmnSFz.jpg',
#    'genre_ids': [10752, 18, 28],
#    'id': 228150,
#    'original_language': 'en',
#    'original_title': 'Fury',
# ...

# %%
response['total_pages']
# Out:
# 39369

# %%
response['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/10c3Hrn1clcSg9PJVl16TARq8Oe.jpg',
#   'genre_ids': [10749, 35],
#   'id': 648743,
#   'original_language': 'es',
#   'original_title': '¿Qué culpa tiene el karma?',
#   'overview': 'The travails of Sara, a frustrated fashion designer who blames karma for her bad luck. Fate will put her face to face with her sister, Lucy, who enjoys very different luck, and in a series of events and reunions that will lead her to make a radical decision.',
#   'popularity': 133.503,
#   'poster_path': '/7BtnZMhU4V8Mq33609UpWvLSHE3.jpg',
#   'release_date': '2022-08-03',
#   'title': "Don't Blame Karma!",
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 168},
#  {'adult': False,
#   'backdrop_path': '/kdbLf3aTQsEXqYlH9vA4fzmnSFz.jpg',
#   'genre_ids': [10752, 18, 28],
#   'id': 228150,
#   'original_language': 'en',
#   'original_title': 'Fury',
# ...

# %%
# for i in response['results']:
#   print(i['title']," ",i['vote_average'])

# %%
df=pd.DataFrame()
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

for i in response['results']:
  popularity.append(i['popularity'])
  vote_count.append(i['vote_count'])
  original_language.append(i['original_language'])
  title.append(i['title'])
  vote_average.append(i['vote_average'])
  overview.append(i['overview'])
  release_date.append(i['release_date'])

d={'title':title,
     'overview':overview,
     'original_language':original_language,
     'release_date':release_date,
     'popularity':popularity,
     'vote_count':vote_count,
     'vote_average':vote_average
     }
df=pd.DataFrame(d)

# %%
df
# Out:
#                                    title  \
# 0                     Don't Blame Karma!
# 1                                   Fury
# 2                               Renfield
# 3                     Oppressive Torture
# 4   The Angry Black Girl and Her Monster
# 5                            Turning Red
# 6                               The Tank
# 7                              The Flood
# 8                   Stand by Me Doraemon
# 9                       Murder Mystery 2
# 10                    Knock at the Cabin
# 11                Fear the Invisible Man
# 12              Minions: The Rise of Gru
# 13                                   AKA
# 14                                Sing 2
# 15    Justice League: Throne of Atlantis
# 16                  The Three Musketeers
# 17                   The First Slam Dunk
# 18                                 Dumbo
# 19                          Home Service
#
#                                              overview original_language  \
# ...

# %%
final_df=pd.DataFrame()
final=pd.DataFrame()
# total pages 500
for j in range(0,500):
  requests.get('https://api.themoviedb.org/3/movie/popular?api_key=c5020a2401b402b3e7ca03a9269573c6&language=en-US&page={}'.format(j)).json()
  popularity=[]
  vote_count=[]
  original_language=[]
  title=[]
  vote_average=[]
  overview=[]
  release_date=[]

  for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])

  data={'title':title,
     'overview':overview,
     'release_date':release_date,
     'popularity':popularity,
     'vote_count':vote_count,
     'vote_average':vote_average
     }

  final_df=pd.DataFrame(data)
  final =final.append(final_df,ignore_index=True)
# Out:
# <ipython-input-39-7383216a1388>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final =final.append(final_df,ignore_index=True)
# <ipython-input-39-7383216a1388>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final =final.append(final_df,ignore_index=True)
# <ipython-input-39-7383216a1388>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final =final.append(final_df,ignore_index=True)
# <ipython-input-39-7383216a1388>:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final =final.append(final_df,ignore_index=True)
# ...

# %%
final
# Out:
#                                      title  \
# 0                       Don't Blame Karma!
# 1                                     Fury
# 2                                 Renfield
# 3                       Oppressive Torture
# 4     The Angry Black Girl and Her Monster
# ...                                    ...
# 9995    Justice League: Throne of Atlantis
# 9996                  The Three Musketeers
# 9997                   The First Slam Dunk
# 9998                                 Dumbo
# 9999                          Home Service
#
#                                                overview release_date  \
# 0     The travails of Sara, a frustrated fashion des...   2022-08-03
# 1     In the last months of World War II, as the All...   2014-10-15
# 2     Having grown sick and tired of his centuries a...   2023-04-07
# 3     In the end of the 19th century, social restora...   1978-01-14
# 4     Vicaria is a brilliant teenager who believes d...   2023-06-09
# ...

# %%
final.to_csv('movies.csv')
